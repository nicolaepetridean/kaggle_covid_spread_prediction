# %% [markdown]
# # ARIMA Forecasting model
# ---

# %%
import os
import numpy as np 
import pandas as pd

from matplotlib import pyplot as plt
from datetime import datetime, timedelta
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.arima_model import ARIMA
from tqdm.notebook import tqdm

import warnings 
warnings.filterwarnings('ignore')

for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/covid19-global-forecasting-week-3/train.csv
# /kaggle/input/covid19-global-forecasting-week-3/submission.csv
# /kaggle/input/covid19-global-forecasting-week-3/test.csv
# /kaggle/input/arimaparams/arima_params
# /kaggle/input/arimaparams3/arima_params
# /kaggle/input/arimaparams2/arima_params
# /kaggle/input/arimaparams4/arima_params

# %% [markdown]
# Read intput and test dataframes from Kaggle.

# %%
trainDf = pd.read_csv("/kaggle/input/covid19-global-forecasting-week-3/train.csv", parse_dates=['Date'])
testDf  = pd.read_csv("/kaggle/input/covid19-global-forecasting-week-3/test.csv", parse_dates=['Date'])  

# get rid of nan
trainDf['Province_State'] = trainDf['Province_State'].fillna('')
testDf['Province_State']  = testDf['Province_State'].fillna('')

# %% [markdown]
# Create a nested dictionary of countries and states

# %%
countries = dict()
for c in trainDf['Country_Region'].unique():
    countryDf = trainDf[trainDf['Country_Region'] == c]
    countries[c] = countryDf['Province_State'].unique()

# %% [markdown]
# Loss functions used for evaluating the model while training

# %%
def RMSLE(pred, target):
    return np.sqrt(np.mean(np.power(np.log(pred + 1) - np.log(target + 1), 2)))

def MSE(pred, target):
    return np.mean(np.power(pred  - target, 2))

# %% [markdown]
# Gicen a range of (P,Q,D) parameters, get the configuration with the best score.

# %%
def get_best_model(dataset,forcast_days, p, d, q):
    maxScore, maxCfg = float("inf"), (0,0,0)
    
    for pParam in range(p):
        for dParam in range(d):
            for qParam in range(q):
                order = (pParam,dParam,qParam)
                try:
                    loss = evaluate_arima(dataset, forcast_days, order)
                    if loss < maxScore:
                        maxScore, maxCfg = loss, order
                except:
                    continue
                    
    print('Cfg %s MSE %.3f' % (maxCfg, maxScore))
    return maxCfg, maxScore

# %% [markdown]
# Evaluate a configuration of ARIMA model.

# %%
def evaluate_arima(data, predDays, arimaPdq):

    # prepare training dataset
    split = int(data.shape[0] * 0.9)
    trainDays, testDays = data[:split], data[split:]
   
    # make predictions
    history   = trainDays
    model     = ARIMA(trainDays, order=arimaPdq)
    modelFit  = model.fit(transparams = True, maxiter = 800)
    
    predictions = modelFit.forecast(steps=testDays.shape[0])[0]
    
    model     = ARIMA(data, order=arimaPdq)
    modelFit  = model.fit(transparams = True, maxiter = 800)
    
    if np.isnan(modelFit.forecast(steps = predDays)[0]).sum()>0:
        return float('inf')

    error = RMSLE(predictions, testDays) 
    return error

# %% [raw]
# Create dataframe for saving the results

# %%
testDf['ConfirmedCases'] = 0
testDf['Fatalities']     = 0

# %% [markdown]
# Iterate each country and make predictions

# %%
def get_arima_params():
    saveDf = testDf.copy()
    for country in tqdm(countries):
        for state in countries[country]:

            print('Country : '+country,'State : '+ state)
            # get country/state data
            dataDf    = trainDf[(trainDf['Province_State'] == state)&(trainDf['Country_Region'] == country)]
            targetDf  = testDf[(testDf['Province_State'] == state)&(testDf['Country_Region']  == country)]
            predDays  = targetDf.shape[0]

            dataDf = dataDf.sort_values(by='Date').reset_index(drop=True)


            if dataDf[dataDf['ConfirmedCases'] > 0].shape[0] > 0:
                dataDf = dataDf[dataDf['ConfirmedCases'] > 0]

            # confirmed cases
            history = dataDf['ConfirmedCases'].to_list()
            if len(history) == 1:
                history.append(history[0])

            # get best config   
            maxCfg, maxScore = get_best_model(np.array(history), predDays, 6, 6, 6)

            # create confirmed predictions
            model         = ARIMA(history, order=maxCfg)
            model_fit     = model.fit(maxiter = 900)
            predConfirmed = model_fit.forecast(steps=predDays)[0]
            
            # align dates
            finalPredConfirmed = dataDf[dataDf['Date'] > targetDf['Date'].min()]['ConfirmedCases']
            predConfirmed = np.concatenate([finalPredConfirmed, predConfirmed[:-finalPredConfirmed.shape[0]]])
            
            
            # fatalities
            history = dataDf['Fatalities'].to_list()
            if len(history) == 1:
                history.append(history[0])

            # get best config
            maxCfg, maxScore = get_best_model(np.array(history), predDays, 6, 6, 6)

            # make predictions
            model      = ARIMA(history, order=maxCfg)
            model_fit  = model.fit(maxiter = 900)
            predDeath  = model_fit.forecast(steps=predDays)[0]
            
            # align dates
            finalPredDeath = dataDf[dataDf['Date'] > targetDf['Date'].min()]['Fatalities']
            predDeath = np.concatenate([finalPredDeath, predDeath[:-finalPredDeath.shape[0]]])
            
            # save results
            tempDf = saveDf[(testDf['Province_State'] == state)&(testDf['Country_Region']  == country)]
            tempDf['Fatalities']     = predDeath
            tempDf['ConfirmedCases'] = predConfirmed
            saveDf[(testDf['Province_State'] == state)&(testDf['Country_Region']  == country)] = tempDf
    return saveDf

# %% [markdown]
# Load arima params because its faster from computer

# %%
def parse_arima_params():
    saveDf = testDf.copy()
    params = []
    with open("/kaggle/input/arimaparams4/arima_params", 'r') as f:
        lines = f.readlines();
        for i in tqdm(range(0,len(lines)-1, 3)):
#              print(lines[i])
            param = []
            line = lines[i].strip().split(':')
            line2 = lines[i+1]
            line3 = lines[i+2]
            
            
            country = line[1][1:-7] # country
            state = line[2][1:]        # state
            cfgConf = [int(line2[5]), int(line2[8]), int(line2[11])] 
            cfgDead = [int(line3[5]), int(line3[8]), int(line3[11])] 
            
            dataDf    = trainDf[(trainDf['Province_State'] == state)&(trainDf['Country_Region'] == country)]
            targetDf  = testDf[(testDf['Province_State'] == state)&(testDf['Country_Region']  == country)]
            predDays  = targetDf.shape[0]

            dataDf = dataDf.sort_values(by='Date').reset_index(drop=True)
            
            if dataDf[dataDf['ConfirmedCases'] > 0].shape[0] > 0:
                dataDf = dataDf[dataDf['ConfirmedCases'] > 0]
            
            # confirmed cases
            history = dataDf['ConfirmedCases'].to_list()
            if len(history) == 1:
                history.append(history[0])
            
            # create confirmed predictions
            model         = ARIMA(history, order=cfgConf)
            model_fit     = model.fit()
            predConfirmed = model_fit.forecast(steps=predDays)[0]
            
            # align dates
            finalPredConfirmed = dataDf[dataDf['Date'] > targetDf['Date'].min()]['ConfirmedCases']
            predConfirmed = np.concatenate([finalPredConfirmed, predConfirmed[:-finalPredConfirmed.shape[0]]])
            
            # fatalities
            history = dataDf['Fatalities'].to_list()
            if len(history) == 1:
                history.append(history[0])

            # make predictions
            model      = ARIMA(history, order=cfgDead)
            model_fit  = model.fit()
            predDeath  = model_fit.forecast(steps=predDays)[0]
            
            # align dates
            finalPredDeath = dataDf[dataDf['Date'] > targetDf['Date'].min()]['Fatalities']
            predDeath = np.concatenate([finalPredDeath, predDeath[:-finalPredDeath.shape[0]]])
            
            # save results
            tempDf = saveDf[(testDf['Province_State'] == state)&(testDf['Country_Region']  == country)]
            tempDf['Fatalities']     = predDeath
            tempDf['ConfirmedCases'] = predConfirmed
            saveDf[(testDf['Province_State'] == state)&(testDf['Country_Region']  == country)] = tempDf
            
    return saveDf

# %%
saveDf = get_arima_params()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=180.0), HTML(value='')))
# Country : Afghanistan State :
# Cfg (3, 0, 0) MSE 0.066
# Cfg (3, 2, 2) MSE 0.103
# Country : Albania State :
# Cfg (1, 2, 0) MSE 0.011
# Cfg (0, 1, 0) MSE 0.027
# Country : Algeria State :
# Cfg (5, 2, 4) MSE 0.151
# Cfg (0, 2, 0) MSE 0.476
# Country : Andorra State :
# Cfg (0, 1, 3) MSE 0.027
# Cfg (1, 2, 0) MSE 0.095
# Country : Angola State :
# Cfg (3, 0, 0) MSE 0.002
# Cfg (0, 2, 0) MSE 0.000
# Country : Antigua and Barbuda State :
# Cfg (0, 2, 2) MSE 0.266
# Cfg (0, 0, 0) MSE 0.000
# Country : Argentina State :
# Cfg (5, 2, 0) MSE 0.055
# Cfg (0, 2, 2) MSE 0.051
# Country : Armenia State :
# Cfg (0, 2, 0) MSE 0.030
# Cfg (0, 2, 3) MSE 0.178
# Country : Australia State : Australian Capital Territory
# Cfg (5, 1, 0) MSE 0.004
# Cfg (0, 2, 0) MSE 0.000
# Country : Australia State : New South Wales
# Cfg (2, 1, 0) MSE 0.032
# Cfg (5, 2, 2) MSE 0.076
# Country : Australia State : Northern Territory
# Cfg (0, 2, 1) MSE 0.018
# Cfg (0, 0, 0) MSE 0.000
# Country : Australia State : Queensland
# Cfg (1, 1, 4) MSE 0.019
# Cfg (3, 2, 0) MSE 0.182
# Country : Australia State : South Australia
# Cfg (0, 2, 0) MSE 0.049
# Cfg (0, 0, 0) MSE 0.000
# Country : Australia State : Tasmania
# Cfg (2, 1, 0) MSE 0.010
# Cfg (0, 0, 0) MSE 1.013
# Country : Australia State : Victoria
# Cfg (0, 2, 5) MSE 0.041
# Cfg (4, 2, 2) MSE 0.129
# Country : Australia State : Western Australia
# Cfg (0, 1, 1) MSE 0.019
# Cfg (3, 1, 1) MSE 0.005
# Country : Austria State :
# Cfg (0, 1, 2) MSE 0.014
# Cfg (1, 1, 0) MSE 0.012
# Country : Azerbaijan State :
# Cfg (1, 2, 1) MSE 0.031
# Cfg (5, 0, 1) MSE 0.043
# Country : Bahamas State :
# Cfg (0, 2, 3) MSE 0.043
# Cfg (2, 1, 0) MSE 0.004
# Country : Bahrain State :
# Cfg (0, 2, 4) MSE 0.037
# Cfg (0, 2, 0) MSE 0.000
# Country : Bangladesh State :
# Cfg (0, 2, 2) MSE 0.018
# Cfg (0, 2, 3) MSE 0.074
# Country : Barbados State :
# Cfg (0, 2, 3) MSE 0.174
# Cfg (0, 0, 0) MSE 0.000
# Country : Belarus State :
# Cfg (1, 2, 0) MSE 0.205
# Cfg (0, 0, 0) MSE 1.310
# Country : Belgium State :
# Cfg (2, 1, 0) MSE 0.078
# Cfg (5, 1, 0) MSE 0.176
# Country : Belize State :
# Cfg (3, 1, 0) MSE 0.062
# Cfg (0, 0, 0) MSE 0.000
# Country : Benin State :
# Cfg (0, 1, 0) MSE 0.075
# Cfg (0, 0, 0) MSE 0.000
# Country : Bhutan State :
# Cfg (3, 2, 1) MSE 0.046
# Cfg (0, 0, 0) MSE 0.000
# Country : Bolivia State :
# Cfg (3, 1, 0) MSE 0.005
# Cfg (0, 2, 2) MSE 0.073
# Country : Bosnia and Herzegovina State :
# Cfg (1, 2, 0) MSE 0.017
# Cfg (1, 1, 0) MSE 0.084
# Country : Botswana State :
# Cfg (0, 0, 0) MSE 0.051
# Cfg (0, 0, 0) MSE 0.134
# Country : Brazil State :
# Cfg (2, 2, 4) MSE 0.262
# Cfg (0, 2, 2) MSE 0.188
# Country : Brunei State :
# Cfg (2, 2, 0) MSE 0.002
# Cfg (0, 2, 0) MSE 0.000
# Country : Bulgaria State :
# Cfg (3, 0, 0) MSE 0.011
# Cfg (5, 2, 0) MSE 0.096
# Country : Burkina Faso State :
# Cfg (0, 1, 4) MSE 0.010
# Cfg (4, 0, 0) MSE 0.034
# Country : Burma State :
# Cfg (1, 1, 0) MSE 0.023
# Cfg (0, 2, 0) MSE 0.000
# Country : Burundi State :
# Cfg (0, 0, 0) MSE 0.182
# Cfg (0, 0, 0) MSE 0.000
# Country : Cabo Verde State :
# Cfg (0, 2, 1) MSE 0.009
# Cfg (0, 2, 0) MSE 0.000
# Country : Cambodia State :
# Cfg (5, 1, 1) MSE 0.013
# Cfg (0, 0, 0) MSE 0.000
# Country : Cameroon State :
# Cfg (0, 2, 0) MSE 0.190
# Cfg (0, 2, 1) MSE 0.086
# Country : Canada State : Alberta
# Cfg (3, 2, 1) MSE 0.103
# Cfg (2, 1, 0) MSE 0.087
# Country : Canada State : British Columbia
# Cfg (0, 2, 3) MSE 0.033
# Cfg (5, 2, 0) MSE 0.239
# Country : Canada State : Manitoba
# Cfg (5, 2, 0) MSE 0.064
# Cfg (1, 2, 2) MSE 0.143
# Country : Canada State : New Brunswick
# Cfg (3, 2, 2) MSE 0.039
# Cfg (0, 0, 0) MSE 0.000
# Country : Canada State : Newfoundland and Labrador
# Cfg (3, 1, 1) MSE 0.002
# Cfg (0, 2, 0) MSE 0.000
# Country : Canada State : Northwest Territories
# Cfg (0, 2, 0) MSE 0.000
# Cfg (0, 0, 0) MSE 0.000
# Country : Canada State : Nova Scotia
# Cfg (2, 1, 0) MSE 0.005
# Cfg (0, 0, 0) MSE 0.000
# Country : Canada State : Ontario
# Cfg (5, 2, 0) MSE 0.115
# Cfg (0, 2, 5) MSE 0.137
# Country : Canada State : Prince Edward Island
# Cfg (3, 0, 0) MSE 0.019
# Cfg (0, 0, 0) MSE 0.000
# Country : Canada State : Quebec
# Cfg (1, 2, 2) MSE 0.020
# Cfg (0, 2, 4) MSE 0.165
# Country : Canada State : Saskatchewan
# Cfg (4, 1, 1) MSE 0.008
# Cfg (0, 1, 5) MSE 0.067
# Country : Canada State : Yukon
# Cfg (3, 0, 0) MSE 0.000
# Cfg (0, 0, 0) MSE 0.000
# Country : Central African Republic State :
# Cfg (5, 1, 2) MSE 0.415
# Cfg (0, 0, 0) MSE 0.000
# Country : Chad State :
# Cfg (1, 2, 0) MSE 0.030
# Cfg (0, 0, 0) MSE 0.000
# Country : Chile State :
# Cfg (2, 2, 0) MSE 0.007
# Cfg (4, 2, 0) MSE 0.415
# Country : China State : Anhui
# Cfg (2, 0, 0) MSE 0.000
# Cfg (5, 2, 0) MSE 0.000
# Country : China State : Beijing
# Cfg (4, 0, 1) MSE 0.007
# Cfg (0, 2, 0) MSE 0.000
# Country : China State : Chongqing
# Cfg (3, 0, 0) MSE 0.001
# Cfg (0, 2, 0) MSE 0.000
# Country : China State : Fujian
# Cfg (2, 0, 1) MSE 0.004
# Cfg (0, 2, 0) MSE 0.000
# Country : China State : Gansu
# Cfg (5, 2, 1) MSE 0.008
# Cfg (0, 2, 0) MSE 0.000
# Country : China State : Guangdong
# Cfg (5, 2, 3) MSE 0.003
# Cfg (0, 2, 0) MSE 0.000
# Country : China State : Guangxi
# Cfg (3, 0, 1) MSE 0.000
# Cfg (0, 2, 0) MSE 0.000
# Country : China State : Guizhou
# Cfg (1, 2, 4) MSE 0.002
# Cfg (0, 2, 0) MSE 0.000
# Country : China State : Hainan
# Cfg (4, 2, 3) MSE 0.001
# Cfg (1, 2, 0) MSE 0.000
# Country : China State : Hebei
# Cfg (4, 1, 4) MSE 0.001
# Cfg (2, 2, 3) MSE 0.007
# Country : China State : Heilongjiang
# Cfg (4, 0, 1) MSE 0.003
# Cfg (1, 0, 0) MSE 0.008
# Country : China State : Henan
# Cfg (0, 2, 3) MSE 0.001
# Cfg (0, 2, 0) MSE 0.000
# Country : China State : Hong Kong
# Cfg (0, 2, 0) MSE 0.055
# Cfg (1, 2, 0) MSE 0.000
# Country : China State : Hubei
# Cfg (0, 2, 0) MSE 0.000
# Cfg (3, 2, 0) MSE 0.001
# Country : China State : Hunan
# Cfg (4, 2, 0) MSE 0.000
# Cfg (0, 2, 0) MSE 0.000
# Country : China State : Inner Mongolia
# Cfg (1, 1, 1) MSE 0.044
# Cfg (0, 2, 0) MSE 0.000
# Country : China State : Jiangsu
# Cfg (2, 0, 1) MSE 0.003
# Cfg (0, 0, 0) MSE 0.000
# Country : China State : Jiangxi
# Cfg (2, 2, 1) MSE 0.000
# Cfg (0, 2, 0) MSE 0.000
# Country : China State : Jilin
# Cfg (3, 0, 2) MSE 0.007
# Cfg (0, 2, 0) MSE 0.000
# Country : China State : Liaoning
# Cfg (2, 0, 1) MSE 0.009
# Cfg (0, 2, 0) MSE 0.000
# Country : China State : Macau
# Cfg (4, 0, 0) MSE 0.025
# Cfg (0, 0, 0) MSE 0.000
# Country : China State : Ningxia
# Cfg (0, 2, 0) MSE 0.000
# Cfg (0, 0, 0) MSE 0.000
# Country : China State : Qinghai
# Cfg (0, 2, 0) MSE 0.000
# Cfg (0, 0, 0) MSE 0.000
# Country : China State : Shaanxi
# Cfg (1, 0, 1) MSE 0.006
# Cfg (0, 2, 0) MSE 0.000
# Country : China State : Shandong
# Cfg (3, 2, 0) MSE 0.002
# Cfg (1, 2, 0) MSE 0.000
# Country : China State : Shanghai
# Cfg (1, 1, 0) MSE 0.008
# Cfg (1, 2, 2) MSE 0.050
# Country : China State : Shanxi
# Cfg (0, 2, 2) MSE 0.002
# Cfg (0, 0, 0) MSE 0.000
# Country : China State : Sichuan
# Cfg (3, 2, 1) MSE 0.001
# Cfg (0, 2, 0) MSE 0.000
# Country : China State : Tianjin
# Cfg (1, 2, 0) MSE 0.024
# Cfg (0, 2, 0) MSE 0.000
# Country : China State : Tibet
# Cfg (0, 1, 0) MSE 0.000
# Cfg (0, 0, 0) MSE 0.000
# Country : China State : Xinjiang
# Cfg (0, 2, 0) MSE 0.000
# Cfg (0, 2, 0) MSE 0.000
# Country : China State : Yunnan
# Cfg (1, 2, 4) MSE 0.005
# Cfg (0, 2, 0) MSE 0.000
# Country : China State : Zhejiang
# Cfg (4, 0, 0) MSE 0.004
# Cfg (0, 2, 0) MSE 0.000
# Country : Colombia State :
# Cfg (3, 1, 1) MSE 0.029
# Cfg (2, 1, 1) MSE 0.080
# Country : Congo (Brazzaville) State :
# Cfg (3, 1, 0) MSE 0.046
# Cfg (0, 0, 0) MSE 1.099
# Country : Congo (Kinshasa) State :
# Cfg (1, 1, 2) MSE 0.044
# Cfg (0, 2, 4) MSE 0.087
# Country : Costa Rica State :
# Cfg (4, 2, 5) MSE 0.006
# Cfg (1, 2, 1) MSE 0.000
# Country : Cote d'Ivoire State :
# Cfg (0, 2, 0) MSE 0.026
# Cfg (0, 2, 0) MSE 0.000
# Country : Croatia State :
# Cfg (2, 0, 0) MSE 0.012
# Cfg (2, 1, 0) MSE 0.077
# Country : Cuba State :
# Cfg (0, 2, 1) MSE 0.014
# Cfg (1, 0, 0) MSE 0.031
# Country : Cyprus State :
# Cfg (0, 2, 0) MSE 0.077
# Cfg (1, 2, 1) MSE 0.011
# Country : Czechia State :
# Cfg (4, 1, 1) MSE 0.018
# Cfg (0, 2, 0) MSE 0.026
# Country : Denmark State : Faroe Islands
# Cfg (4, 0, 0) MSE 0.017
# Cfg (0, 0, 0) MSE 0.000
# Country : Denmark State : Greenland
# Cfg (0, 2, 0) MSE 0.000
# Cfg (0, 0, 0) MSE 0.000
# Country : Denmark State :
# Cfg (1, 2, 2) MSE 0.069
# Cfg (5, 2, 0) MSE 0.076
# Country : Diamond Princess State :
# Cfg (0, 2, 0) MSE 0.000
# Cfg (2, 1, 2) MSE 0.017
# Country : Djibouti State :
# Cfg (4, 2, 0) MSE 0.023
# Cfg (0, 0, 0) MSE 0.000
# Country : Dominica State :
# Cfg (1, 2, 0) MSE 0.003
# Cfg (0, 0, 0) MSE 0.000
# Country : Dominican Republic State :
# Cfg (4, 2, 4) MSE 0.074
# Cfg (1, 2, 3) MSE 0.035
# Country : Ecuador State :
# Cfg (0, 1, 4) MSE 0.104
# Cfg (2, 2, 0) MSE 0.313
# Country : Egypt State :
# Cfg (0, 2, 5) MSE 0.071
# Cfg (3, 2, 3) MSE 0.018
# Country : El Salvador State :
# Cfg (0, 2, 3) MSE 0.034
# Cfg (1, 2, 0) MSE 0.037
# Country : Equatorial Guinea State :
# Cfg (0, 2, 5) MSE 0.022
# Cfg (0, 0, 0) MSE 0.000
# Country : Eritrea State :
# Cfg (3, 2, 0) MSE 0.018
# Cfg (0, 0, 0) MSE 0.000
# Country : Estonia State :
# Cfg (5, 2, 1) MSE 0.027
# Cfg (1, 2, 0) MSE 0.341
# Country : Eswatini State :
# Cfg (0, 2, 0) MSE 0.000
# Cfg (0, 0, 0) MSE 0.000
# Country : Ethiopia State :
# Cfg (5, 2, 1) MSE 0.044
# Cfg (0, 0, 0) MSE 0.000
# Country : Fiji State :
# Cfg (0, 1, 0) MSE 0.215
# Cfg (0, 0, 0) MSE 0.000
# Country : Finland State :
# Cfg (2, 2, 1) MSE 0.030
# Cfg (4, 0, 0) MSE 0.048
# Country : France State : French Guiana
# Cfg (1, 2, 1) MSE 0.041
# Cfg (0, 0, 0) MSE 0.000
# Country : France State : French Polynesia
# Cfg (3, 0, 0) MSE 0.029
# Cfg (0, 0, 0) MSE 0.000
# Country : France State : Guadeloupe
# Cfg (3, 2, 0) MSE 0.020
# Cfg (2, 2, 0) MSE 0.078
# Country : France State : Martinique
# Cfg (0, 1, 0) MSE 0.008
# Cfg (1, 1, 0) MSE 0.027
# Country : France State : Mayotte
# Cfg (2, 2, 0) MSE 0.058
# Cfg (4, 1, 4) MSE 0.117
# Country : France State : New Caledonia
# Cfg (4, 1, 0) MSE 0.021
# Cfg (0, 0, 0) MSE 0.000
# Country : France State : Reunion
# Cfg (3, 1, 0) MSE 0.021
# Cfg (0, 0, 0) MSE 0.000
# Country : France State : Saint Barthelemy
# Cfg (3, 1, 1) MSE 0.002
# Cfg (0, 0, 0) MSE 0.000
# Country : France State : St Martin
# Cfg (4, 1, 4) MSE 0.077
# Cfg (0, 2, 0) MSE 0.000
# Country : France State :
# Cfg (4, 2, 1) MSE 0.027
# Cfg (2, 2, 4) MSE 0.106
# Country : Gabon State :
# Cfg (0, 2, 1) MSE 0.042
# Cfg (0, 2, 0) MSE 0.000
# Country : Gambia State :
# Cfg (0, 2, 0) MSE 0.000
# Cfg (0, 2, 0) MSE 0.000
# Country : Georgia State :
# Cfg (0, 2, 4) MSE 0.042
# Cfg (0, 0, 0) MSE 0.000
# Country : Germany State :
# Cfg (3, 1, 0) MSE 0.060
# Cfg (4, 2, 0) MSE 0.053
# Country : Ghana State :
# Cfg (0, 2, 2) MSE 0.061
# Cfg (0, 2, 0) MSE 0.000
# Country : Greece State :
# Cfg (1, 2, 1) MSE 0.022
# Cfg (1, 2, 2) MSE 0.041
# Country : Grenada State :
# Cfg (4, 1, 0) MSE 0.037
# Cfg (0, 0, 0) MSE 0.000
# Country : Guatemala State :
# Cfg (0, 2, 3) MSE 0.063
# Cfg (0, 2, 0) MSE 0.000
# Country : Guinea State :
# Cfg (3, 2, 0) MSE 0.405
# Cfg (0, 0, 0) MSE 0.000
# Country : Guinea-Bissau State :
# Cfg (3, 1, 0) MSE 0.301
# Cfg (0, 0, 0) MSE 0.000
# Country : Guyana State :
# Cfg (0, 2, 0) MSE 0.112
# Cfg (3, 2, 0) MSE 0.199
# Country : Haiti State :
# Cfg (1, 2, 0) MSE 0.031
# Cfg (0, 0, 0) MSE 0.000
# Country : Holy See State :
# Cfg (3, 1, 0) MSE 0.046
# Cfg (0, 0, 0) MSE 0.000
# Country : Honduras State :
# Cfg (0, 2, 1) MSE 0.138
# Cfg (0, 2, 5) MSE 0.159
# Country : Hungary State :
# Cfg (1, 1, 1) MSE 0.012
# Cfg (2, 2, 0) MSE 0.054
# Country : Iceland State :
# Cfg (4, 2, 0) MSE 0.010
# Cfg (3, 2, 1) MSE 0.250
# Country : India State :
# Cfg (0, 2, 2) MSE 0.152
# Cfg (0, 2, 2) MSE 0.222
# Country : Indonesia State :
# Cfg (5, 2, 1) MSE 0.011
# Cfg (4, 2, 0) MSE 0.047
# Country : Iran State :
# Cfg (2, 1, 3) MSE 0.004
# Cfg (0, 2, 0) MSE 0.002
# Country : Iraq State :
# Cfg (0, 1, 4) MSE 0.024
# Cfg (0, 2, 4) MSE 0.009
# Country : Ireland State :
# Cfg (0, 2, 0) MSE 0.016
# Cfg (4, 2, 0) MSE 0.043
# Country : Israel State :
# Cfg (2, 2, 0) MSE 0.020
# Cfg (0, 2, 5) MSE 0.110
# Country : Italy State :
# Cfg (1, 1, 0) MSE 0.012
# Cfg (3, 1, 0) MSE 0.006
# Country : Jamaica State :
# Cfg (3, 2, 0) MSE 0.099
# Cfg (4, 1, 4) MSE 0.353
# Country : Japan State :
# Cfg (1, 2, 0) MSE 0.112
# Cfg (5, 1, 2) MSE 0.017
# Country : Jordan State :
# Cfg (0, 2, 0) MSE 0.018
# Cfg (1, 0, 0) MSE 0.049
# Country : Kazakhstan State :
# Cfg (1, 2, 0) MSE 0.016
# Cfg (0, 2, 0) MSE 0.159
# Country : Kenya State :
# Cfg (0, 2, 0) MSE 0.279
# Cfg (4, 2, 2) MSE 0.342
# Country : Korea, South State :
# Cfg (5, 0, 1) MSE 0.002
# Cfg (3, 1, 1) MSE 0.016
# Country : Kosovo State :
# Cfg (1, 2, 0) MSE 0.019
# Cfg (0, 0, 0) MSE 0.000
# Country : Kuwait State :
# Cfg (0, 2, 4) MSE 0.066
# Cfg (0, 0, 0) MSE 0.000
# Country : Kyrgyzstan State :
# Cfg (0, 1, 5) MSE 0.024
# Cfg (0, 0, 0) MSE 0.490
# Country : Laos State :
# Cfg (3, 2, 0) MSE 0.024
# Cfg (0, 0, 0) MSE 0.000
# Country : Latvia State :
# Cfg (0, 2, 0) MSE 0.021
# Cfg (0, 0, 0) MSE 0.347
# Country : Lebanon State :
# Cfg (0, 1, 2) MSE 0.008
# Cfg (2, 2, 0) MSE 0.049
# Country : Liberia State :
# Cfg (3, 1, 2) MSE 0.028
# Cfg (0, 0, 0) MSE 0.000
# Country : Libya State :
# Cfg (1, 2, 0) MSE 0.049
# Cfg (0, 0, 0) MSE 0.693
# Country : Liechtenstein State :
# Cfg (5, 2, 2) MSE 0.031
# Cfg (0, 0, 0) MSE 0.000
# Country : Lithuania State :
# Cfg (0, 2, 1) MSE 0.010
# Cfg (0, 2, 2) MSE 0.054
# Country : Luxembourg State :
# Cfg (4, 2, 3) MSE 0.017
# Cfg (4, 2, 0) MSE 0.054
# Country : MS Zaandam State :
# Cfg (0, 2, 0) MSE 0.000
# Cfg (0, 2, 0) MSE 0.000
# Country : Madagascar State :
# Cfg (0, 1, 1) MSE 0.048
# Cfg (0, 0, 0) MSE 0.000
# Country : Malaysia State :
# Cfg (2, 1, 0) MSE 0.016
# Cfg (0, 2, 5) MSE 0.043
# Country : Maldives State :
# Cfg (5, 1, 2) MSE 0.010
# Cfg (0, 0, 0) MSE 0.000
# Country : Mali State :
# Cfg (0, 0, 2) MSE 0.015
# Cfg (0, 2, 0) MSE 0.000
# Country : Malta State :
# Cfg (0, 2, 0) MSE 0.031
# Cfg (0, 0, 0) MSE 0.000
# Country : Mauritania State :
# Cfg (3, 0, 0) MSE 0.023
# Cfg (0, 2, 0) MSE 0.000
# Country : Mauritius State :
# Cfg (5, 1, 0) MSE 0.011
# Cfg (3, 1, 0) MSE 0.016
# Country : Mexico State :
# Cfg (2, 1, 0) MSE 0.040
# Cfg (1, 2, 4) MSE 0.089
# Country : Moldova State :
# Cfg (0, 2, 0) MSE 0.074
# Cfg (2, 2, 0) MSE 0.043
# Country : Monaco State :
# Cfg (3, 2, 0) MSE 0.012
# Cfg (0, 2, 0) MSE 0.000
# Country : Mongolia State :
# Cfg (5, 1, 2) MSE 0.023
# Cfg (0, 0, 0) MSE 0.000
# Country : Montenegro State :
# Cfg (1, 2, 0) MSE 0.069
# Cfg (0, 2, 0) MSE 0.000
# Country : Morocco State :
# Cfg (0, 1, 4) MSE 0.050
# Cfg (4, 2, 2) MSE 0.023
# Country : Mozambique State :
# Cfg (1, 0, 0) MSE 0.035
# Cfg (0, 0, 0) MSE 0.000
# Country : Namibia State :
# Cfg (2, 2, 0) MSE 0.071
# Cfg (0, 0, 0) MSE 0.000
# Country : Nepal State :
# Cfg (5, 1, 0) MSE 0.091
# Cfg (0, 0, 0) MSE 0.000
# Country : Netherlands State : Aruba
# Cfg (2, 1, 2) MSE 0.013
# Cfg (0, 0, 0) MSE 0.000
# Country : Netherlands State : Curacao
# Cfg (0, 2, 0) MSE 0.000
# Cfg (3, 2, 0) MSE 0.000
# Country : Netherlands State : Sint Maarten
# Cfg (0, 2, 1) MSE 0.046
# Cfg (0, 2, 1) MSE 0.140
# Country : Netherlands State :
# Cfg (2, 1, 1) MSE 0.004
# Cfg (5, 2, 0) MSE 0.055
# Country : New Zealand State :
# Cfg (4, 2, 1) MSE 0.013
# Cfg (0, 2, 0) MSE 0.000
# Country : Nicaragua State :
# Cfg (0, 2, 0) MSE 0.000
# Cfg (0, 2, 0) MSE 0.000
# Country : Niger State :
# Cfg (0, 2, 1) MSE 0.083
# Cfg (0, 1, 2) MSE 0.044
# Country : Nigeria State :
# Cfg (1, 1, 1) MSE 0.057
# Cfg (0, 2, 1) MSE 0.177
# Country : North Macedonia State :
# Cfg (0, 2, 0) MSE 0.056
# Cfg (1, 2, 0) MSE 0.068
# Country : Norway State :
# Cfg (5, 2, 0) MSE 0.006
# Cfg (1, 2, 0) MSE 0.050
# Country : Oman State :
# Cfg (5, 2, 0) MSE 0.009
# Cfg (0, 0, 0) MSE 0.693
# Country : Pakistan State :
# Cfg (3, 2, 5) MSE 0.104
# Cfg (2, 2, 0) MSE 0.030
# Country : Panama State :
# Cfg (0, 1, 0) MSE 0.059
# Cfg (0, 1, 1) MSE 0.052
# Country : Papua New Guinea State :
# Cfg (0, 1, 0) MSE 0.000
# Cfg (0, 0, 0) MSE 0.000
# Country : Paraguay State :
# Cfg (4, 2, 1) MSE 0.052
# Cfg (5, 2, 0) MSE 0.000
# Country : Peru State :
# Cfg (1, 2, 3) MSE 0.063
# Cfg (4, 1, 0) MSE 0.108
# Country : Philippines State :
# Cfg (5, 2, 3) MSE 0.491
# Cfg (0, 2, 0) MSE 0.062
# Country : Poland State :
# Cfg (5, 2, 0) MSE 0.035
# Cfg (0, 2, 0) MSE 0.126
# Country : Portugal State :
# Cfg (4, 2, 0) MSE 0.044
# Cfg (0, 2, 0) MSE 0.031
# Country : Qatar State :
# Cfg (0, 2, 0) MSE 0.075
# Cfg (0, 2, 4) MSE 0.095
# Country : Romania State :
# Cfg (0, 2, 3) MSE 0.043
# Cfg (0, 2, 1) MSE 0.029
# Country : Russia State :
# Cfg (4, 2, 0) MSE 0.069
# Cfg (0, 2, 0) MSE 0.701
# Country : Rwanda State :
# Cfg (4, 1, 0) MSE 0.005
# Cfg (0, 0, 0) MSE 0.000
# Country : Saint Kitts and Nevis State :
# Cfg (2, 0, 0) MSE 0.062
# Cfg (0, 0, 0) MSE 0.000
# Country : Saint Lucia State :
# Cfg (0, 2, 4) MSE 0.011
# Cfg (0, 0, 0) MSE 0.000
# Country : Saint Vincent and the Grenadines State :
# Cfg (0, 1, 0) MSE 0.464
# Cfg (0, 0, 0) MSE 0.000
# Country : San Marino State :
# Cfg (0, 2, 2) MSE 0.010
# Cfg (4, 2, 0) MSE 0.028
# Country : Saudi Arabia State :
# Cfg (1, 2, 0) MSE 0.007
# Cfg (0, 2, 2) MSE 0.270
# Country : Senegal State :
# Cfg (2, 0, 0) MSE 0.012
# Cfg (0, 0, 0) MSE 0.600
# Country : Serbia State :
# Cfg (0, 2, 3) MSE 0.075
# Cfg (3, 2, 0) MSE 0.298
# Country : Seychelles State :
# Cfg (1, 0, 0) MSE 0.023
# Cfg (0, 0, 0) MSE 0.000
# Country : Sierra Leone State :
# Cfg (0, 0, 0) MSE 0.118
# Cfg (0, 0, 0) MSE 0.000
# Country : Singapore State :
# Cfg (5, 1, 0) MSE 0.012
# Cfg (5, 2, 2) MSE 0.175
# Country : Slovakia State :
# Cfg (4, 2, 0) MSE 0.013
# Cfg (3, 0, 1) MSE 0.514
# Country : Slovenia State :
# Cfg (1, 2, 0) MSE 0.006
# Cfg (0, 2, 2) MSE 0.047
# Country : Somalia State :
# Cfg (2, 2, 0) MSE 0.081
# Cfg (0, 0, 0) MSE 0.000
# Country : South Africa State :
# Cfg (2, 2, 2) MSE 0.008
# Cfg (0, 1, 4) MSE 0.205
# Country : Spain State :
# Cfg (3, 1, 0) MSE 0.008
# Cfg (4, 1, 0) MSE 0.004
# Country : Sri Lanka State :
# Cfg (0, 2, 4) MSE 0.122
# Cfg (0, 0, 0) MSE 1.223
# Country : Sudan State :
# Cfg (1, 2, 0) MSE 0.067
# Cfg (0, 2, 0) MSE 0.000
# Country : Suriname State :
# Cfg (4, 1, 2) MSE 0.021
# Cfg (0, 0, 0) MSE 0.400
# Country : Sweden State :
# Cfg (1, 2, 2) MSE 0.111
# Cfg (2, 2, 0) MSE 0.200
# Country : Switzerland State :
# Cfg (5, 1, 0) MSE 0.007
# Cfg (0, 2, 0) MSE 0.026
# Country : Syria State :
# Cfg (0, 2, 2) MSE 0.192
# Cfg (0, 2, 0) MSE 0.000
# Country : Taiwan* State :
# Cfg (2, 1, 5) MSE 0.017
# Cfg (5, 2, 1) MSE 0.450
# Country : Tanzania State :
# Cfg (2, 0, 1) MSE 0.004
# Cfg (0, 2, 0) MSE 0.000
# Country : Thailand State :
# Cfg (1, 2, 1) MSE 0.013
# Cfg (2, 2, 0) MSE 0.195
# Country : Timor-Leste State :
# Cfg (0, 0, 0) MSE 0.000
# Cfg (0, 0, 0) MSE 0.000
# Country : Togo State :
# Cfg (1, 1, 0) MSE 0.017
# Cfg (4, 2, 0) MSE 0.140
# Country : Trinidad and Tobago State :
# Cfg (0, 1, 0) MSE 0.032
# Cfg (0, 2, 1) MSE 0.256
# Country : Tunisia State :
# Cfg (5, 2, 0) MSE 0.087
# Cfg (1, 2, 1) MSE 0.240
# Country : Turkey State :
# Cfg (5, 1, 0) MSE 0.022
# Cfg (0, 2, 4) MSE 0.080
# Country : US State : Alabama
# Cfg (5, 2, 2) MSE 0.049
# Cfg (0, 2, 1) MSE 0.032
# Country : US State : Alaska
# Cfg (2, 2, 0) MSE 0.016
# Cfg (0, 2, 0) MSE 0.000
# Country : US State : Arizona
# Cfg (1, 2, 0) MSE 0.022
# Cfg (0, 2, 0) MSE 0.058
# Country : US State : Arkansas
# Cfg (0, 2, 5) MSE 0.008
# Cfg (4, 2, 0) MSE 0.043
# Country : US State : California
# Cfg (1, 2, 0) MSE 0.012
# Cfg (4, 1, 0) MSE 0.016
# Country : US State : Colorado
# Cfg (3, 0, 0) MSE 0.036
# Cfg (0, 1, 3) MSE 0.070
# Country : US State : Connecticut
# Cfg (1, 1, 0) MSE 0.061
# Cfg (1, 2, 0) MSE 0.162
# Country : US State : Delaware
# Cfg (4, 2, 0) MSE 0.008
# Cfg (2, 1, 0) MSE 0.034
# Country : US State : District of Columbia
# Cfg (0, 2, 3) MSE 0.013
# Cfg (0, 2, 2) MSE 0.101
# Country : US State : Florida
# Cfg (0, 2, 2) MSE 0.067
# Cfg (0, 2, 0) MSE 0.180
# Country : US State : Georgia
# Cfg (1, 1, 0) MSE 0.023
# Cfg (0, 2, 0) MSE 0.022
# Country : US State : Guam
# Cfg (0, 1, 0) MSE 0.015
# Cfg (0, 2, 1) MSE 0.074
# Country : US State : Hawaii
# Cfg (0, 2, 0) MSE 0.050
# Cfg (0, 1, 5) MSE 0.800
# Country : US State : Idaho
# Cfg (5, 1, 0) MSE 0.077
# Cfg (2, 0, 0) MSE 0.026
# Country : US State : Illinois
# Cfg (2, 2, 0) MSE 0.007
# Cfg (0, 2, 0) MSE 0.101
# Country : US State : Indiana
# Cfg (0, 2, 0) MSE 0.018
# Cfg (0, 2, 0) MSE 0.042
# Country : US State : Iowa
# Cfg (0, 2, 4) MSE 0.025
# Cfg (0, 1, 3) MSE 0.034
# Country : US State : Kansas
# Cfg (1, 2, 0) MSE 0.012
# Cfg (2, 2, 0) MSE 0.155
# Country : US State : Kentucky
# Cfg (0, 2, 5) MSE 0.069
# Cfg (5, 2, 0) MSE 0.610
# Country : US State : Louisiana
# Cfg (0, 2, 0) MSE 0.110
# Cfg (3, 1, 0) MSE 0.033
# Country : US State : Maine
# Cfg (0, 2, 1) MSE 0.070
# Cfg (3, 2, 0) MSE 0.058
# Country : US State : Maryland
# Cfg (0, 2, 0) MSE 0.075
# Cfg (3, 2, 0) MSE 0.140
# Country : US State : Massachusetts
# Cfg (0, 2, 0) MSE 0.064
# Cfg (0, 2, 0) MSE 0.029
# Country : US State : Michigan
# Cfg (0, 2, 0) MSE 0.087
# Cfg (0, 2, 3) MSE 0.015
# Country : US State : Minnesota
# Cfg (2, 0, 0) MSE 0.011
# Cfg (0, 2, 2) MSE 0.135
# Country : US State : Mississippi
# Cfg (4, 2, 1) MSE 0.024
# Cfg (2, 2, 0) MSE 0.015
# Country : US State : Missouri
# Cfg (0, 2, 4) MSE 0.042
# Cfg (0, 2, 0) MSE 0.112
# Country : US State : Montana
# Cfg (4, 1, 0) MSE 0.024
# Cfg (1, 1, 0) MSE 0.103
# Country : US State : Nebraska
# Cfg (0, 2, 3) MSE 0.007
# Cfg (0, 2, 0) MSE 0.029
# Country : US State : Nevada
# Cfg (1, 2, 1) MSE 0.031
# Cfg (0, 2, 3) MSE 0.028
# Country : US State : New Hampshire
# Cfg (0, 1, 1) MSE 0.154
# Cfg (3, 2, 2) MSE 0.129
# Country : US State : New Jersey
# Cfg (3, 2, 0) MSE 0.055
# Cfg (2, 1, 0) MSE 0.136
# Country : US State : New Mexico
# Cfg (1, 2, 0) MSE 0.092
# Cfg (1, 2, 0) MSE 0.192
# Country : US State : New York
# Cfg (1, 1, 0) MSE 0.011
# Cfg (2, 2, 2) MSE 0.011
# Country : US State : North Carolina
# Cfg (0, 2, 0) MSE 0.033
# Cfg (0, 2, 0) MSE 0.125
# Country : US State : North Dakota
# Cfg (3, 2, 1) MSE 0.025
# Cfg (1, 0, 0) MSE 0.044
# Country : US State : Ohio
# Cfg (5, 2, 0) MSE 0.007
# Cfg (0, 2, 3) MSE 0.027
# Country : US State : Oklahoma
# Cfg (5, 2, 0) MSE 0.109
# Cfg (1, 2, 0) MSE 0.069
# Country : US State : Oregon
# Cfg (4, 1, 0) MSE 0.015
# Cfg (3, 0, 0) MSE 0.021
# Country : US State : Pennsylvania
# Cfg (4, 2, 1) MSE 0.056
# Cfg (1, 2, 0) MSE 0.013
# Country : US State : Puerto Rico
# Cfg (0, 1, 2) MSE 0.032
# Cfg (0, 2, 0) MSE 0.048
# Country : US State : Rhode Island
# Cfg (1, 2, 1) MSE 0.015
# Cfg (0, 2, 2) MSE 0.050
# Country : US State : South Carolina
# Cfg (5, 2, 1) MSE 0.037
# Cfg (0, 2, 0) MSE 0.021
# Country : US State : South Dakota
# Cfg (0, 2, 5) MSE 0.095
# Cfg (0, 1, 0) MSE 0.405
# Country : US State : Tennessee
# Cfg (0, 1, 1) MSE 0.037
# Cfg (0, 2, 5) MSE 0.093
# Country : US State : Texas
# Cfg (1, 2, 0) MSE 0.016
# Cfg (1, 2, 4) MSE 0.097
# Country : US State : Utah
# Cfg (5, 2, 0) MSE 0.050
# Cfg (0, 2, 2) MSE 0.075
# Country : US State : Vermont
# Cfg (0, 2, 4) MSE 0.022
# Cfg (0, 2, 1) MSE 0.073
# Country : US State : Virgin Islands
# Cfg (2, 1, 0) MSE 0.059
# Cfg (0, 0, 0) MSE 0.000
# Country : US State : Virginia
# Cfg (0, 2, 0) MSE 0.012
# Cfg (0, 2, 1) MSE 0.181
# Country : US State : Washington
# Cfg (4, 1, 0) MSE 0.028
# Cfg (0, 2, 0) MSE 0.029
# Country : US State : West Virginia
# Cfg (4, 1, 0) MSE 0.006
# Cfg (3, 2, 0) MSE 0.101
# Country : US State : Wisconsin
# Cfg (0, 2, 5) MSE 0.010
# Cfg (0, 2, 0) MSE 0.137
# Country : US State : Wyoming
# Cfg (4, 1, 2) MSE 0.031
# Cfg (0, 0, 0) MSE 0.000
# Country : Uganda State :
# Cfg (5, 0, 0) MSE 0.055
# Cfg (0, 0, 0) MSE 0.000
# Country : Ukraine State :
# Cfg (5, 2, 0) MSE 0.023
# Cfg (0, 2, 0) MSE 0.037
# Country : United Arab Emirates State :
# Cfg (0, 2, 0) MSE 0.132
# Cfg (5, 2, 1) MSE 0.672
# Country : United Kingdom State : Anguilla
# Cfg (1, 1, 0) MSE 0.005
# Cfg (0, 0, 0) MSE 0.000
# Country : United Kingdom State : Bermuda
# Cfg (1, 2, 0) MSE 0.027
# Cfg (0, 0, 0) MSE 0.000
# Country : United Kingdom State : British Virgin Islands
# Cfg (0, 2, 0) MSE 0.000
# Cfg (0, 0, 0) MSE 0.000
# Country : United Kingdom State : Cayman Islands
# Cfg (1, 2, 0) MSE 0.248
# Cfg (0, 2, 0) MSE 0.000
# Country : United Kingdom State : Channel Islands
# Cfg (5, 2, 0) MSE 0.072
# Cfg (0, 1, 2) MSE 0.079
# Country : United Kingdom State : Gibraltar
# Cfg (2, 2, 0) MSE 0.051
# Cfg (0, 0, 0) MSE 0.000
# Country : United Kingdom State : Isle of Man
# Cfg (5, 2, 0) MSE 0.210
# Cfg (2, 1, 0) MSE 0.006
# Country : United Kingdom State : Montserrat
# Cfg (0, 2, 2) MSE 0.049
# Cfg (0, 0, 0) MSE 0.000
# Country : United Kingdom State : Turks and Caicos Islands
# Cfg (0, 0, 3) MSE 0.008
# Cfg (0, 0, 0) MSE 0.000
# Country : United Kingdom State :
# Cfg (3, 2, 0) MSE 0.039
# Cfg (4, 1, 0) MSE 0.123
# Country : Uruguay State :
# Cfg (2, 1, 4) MSE 0.027
# Cfg (0, 2, 5) MSE 0.270
# Country : Uzbekistan State :
# Cfg (0, 2, 5) MSE 0.006
# Cfg (0, 2, 0) MSE 0.000
# Country : Venezuela State :
# Cfg (4, 0, 0) MSE 0.008
# Cfg (0, 2, 5) MSE 0.135
# Country : Vietnam State :
# Cfg (3, 2, 1) MSE 0.017
# Cfg (0, 0, 0) MSE 0.000
# Country : West Bank and Gaza State :
# Cfg (5, 2, 0) MSE 0.179
# Cfg (0, 2, 0) MSE 0.000
# Country : Zambia State :
# Cfg (5, 2, 0) MSE 0.006
# Cfg (0, 0, 0) MSE 0.693
# Country : Zimbabwe State :
# Cfg (0, 1, 0) MSE 0.032
# Cfg (0, 2, 0) MSE 0.000

# %% [markdown]
# Save prediction

# %%
output=pd.DataFrame()
output['ForecastId']     = saveDf['ForecastId'].astype(np.int32)
output['ConfirmedCases'] = saveDf['ConfirmedCases'].astype(np.int32)
output['Fatalities']     = saveDf['Fatalities'].astype(np.int32)
output.to_csv('submission.csv', index=False)
output
# Out:
#        ForecastId  ConfirmedCases  Fatalities
# 0               1             110           4
# 1               2             110           4
# 2               3             120           4
# 3               4             170           4
# 4               5             174           4
# ...           ...             ...         ...
# 13153       13154              26           1
# 13154       13155              27           1
# 13155       13156              27           1
# 13156       13157              28           1
# 13157       13158              29           1
#
# [13158 rows x 3 columns]
